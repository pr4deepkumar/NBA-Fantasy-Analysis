# %% [markdown]
# ## SquadUP!
#
# The goal of this Analysis is to use the previous year (2019-2020) NBA Regular Season Stats and come up with a system that identifies Players that generate the most Fantasy Points and set it as the benchmark to be utilized for Identifying the Top Players from Each Position that we would like to have in our Fantasy Squad for the Upcoming NBA Season!

# %% [markdown]
# ### Importing the Necessary Packages

# %%
# importing necessary packages

# for numerical/scientific calculations
import numpy as np

# for data manipulation
import pandas as pd

# for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# for metrics
from sklearn.metrics import classification_report,accuracy_score

# to ignore/not display warnings
import warnings
warnings.filterwarnings(action='ignore')

# %%
nba_df = pd.read_excel('NBA20-21.xlsx')
pd.set_option('display.max_columns', None)

# %%
nba_df.head(5)
# Out:
#                   FULL NAME  POS    AGE TEAM  GP   MPG   PPG   RPG  APG   SPG  \
# 0              Steven Adams    C  27.07  Okc  63  26.7  10.9   9.3  2.3  0.81
# 1               Bam Adebayo  C-F  23.08  Mia  72  33.6  15.9  10.2  5.1  1.14
# 2         LaMarcus Aldridge  F-C  35.07  San  53  33.1  18.9   7.4  2.4  0.68
# 3            Kyle Alexander  F-C  23.81  Mia   2   6.7   1.0   1.5  0.0  0.00
# 4  Nickeil Alexander-Walker    G  21.95  Nor  47  12.6   5.7   1.8  1.9  0.36
#
#     BPG  TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  \
# 0  1.06  1.51  201  0.582  475  0.594    3  0.333   9.2  122.0  101.9  55.6
# 1  1.29  2.82  382  0.691  777  0.564   14  0.143  11.2  116.2  102.2  69.9
# 2  1.64  1.40  191  0.827  637  0.518  157  0.389   8.4  114.7  109.1  68.9
# 3  0.00  0.50    0  0.000    2  0.500    0  0.000   0.0   96.0  108.8  14.0
# 4  0.17  1.15   37  0.676  133  0.391  133  0.346   8.5   93.2  106.4  26.2
#
#    USG%   TO%   eFG%    TS%  TRB%  AST%
# 0  17.3  14.4  0.593  0.604  19.2  13.2
# 1  21.2  17.5  0.558  0.597  17.0  24.2
# 2  23.4   7.8  0.531  0.570  12.0  11.4
# 3   9.9  33.3  0.500  0.500  12.5   0.0
# 4  23.3  16.1  0.455  0.473   7.5  21.1

# %%
nba_df['TEAM'] = nba_df['TEAM'].str.upper()

# %%
nba_df
# Out:
#                     FULL NAME  POS    AGE TEAM  GP   MPG   PPG   RPG  APG  \
# 0                Steven Adams    C  27.07  OKC  63  26.7  10.9   9.3  2.3
# 1                 Bam Adebayo  C-F  23.08  MIA  72  33.6  15.9  10.2  5.1
# 2           LaMarcus Aldridge  F-C  35.07  SAN  53  33.1  18.9   7.4  2.4
# 3              Kyle Alexander  F-C  23.81  MIA   2   6.7   1.0   1.5  0.0
# 4    Nickeil Alexander-Walker    G  21.95  NOR  47  12.6   5.7   1.8  1.9
# ..                        ...  ...    ...  ...  ..   ...   ...   ...  ...
# 586                Trae Young    G  21.90  ATL  60  35.3  29.6   4.2  9.3
# 587               Cody Zeller    C  27.86  CHA  58  23.1  11.1   7.1  1.5
# 588              Tyler Zeller  F-C  30.58  SAN   2   2.0   1.0   2.0  0.0
# 589                Ante Zizic    C  23.61  CLE  22  10.0   4.4   3.0  0.3
# 590               Ivica Zubac    C  23.41  LAC  72  18.4   8.3   7.6  1.1
#
#       SPG   BPG  TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  \
# 0    0.81  1.06  1.51  201  0.582  475  0.594    3  0.333   9.2  122.0  101.9
# 1    1.14  1.29  2.82  382  0.691  777  0.564   14  0.143  11.2  116.2  102.2
# 2    0.68  1.64  1.40  191  0.827  637  0.518  157  0.389   8.4  114.7  109.1
# 3    0.00  0.00  0.50    0  0.000    2  0.500    0  0.000   0.0   96.0  108.8
# 4    0.36  0.17  1.15   37  0.676  133  0.391  133  0.346   8.5   93.2  106.4
# ..    ...   ...   ...  ...    ...  ...    ...  ...    ...   ...    ...    ...
# 586  1.08  0.13  4.80  559  0.860  681  0.501  568  0.361  11.9  113.9  115.2
# 587  0.69  0.43  1.29  179  0.682  405  0.575   75  0.240   8.5  115.2  103.0
# 588  0.00  0.00  0.00    0  0.000    4  0.250    0  0.000   0.0    0.0    0.0
# 589  0.32  0.23  0.45   19  0.737   72  0.569    0  0.000   6.3  115.0  102.9
# 590  0.22  0.92  0.85  166  0.747  385  0.613    2  0.000   8.9  132.1   95.4
#
#      MIN%  USG%   TO%   eFG%    TS%  TRB%  AST%
# 0    55.6  17.3  14.4  0.593  0.604  19.2  13.2
# 1    69.9  21.2  17.5  0.558  0.597  17.0  24.2
# 2    68.9  23.4   7.8  0.531  0.570  12.0  11.4
# 3    14.0   9.9  33.3  0.500  0.500  12.5   0.0
# 4    26.2  23.3  16.1  0.455  0.473   7.5  21.1
# ..    ...   ...   ...    ...    ...   ...   ...
# 586  73.6  34.9  16.2  0.519  0.595   6.4  45.6
# 587  48.2  20.8  11.8  0.542  0.574  16.8  11.3
# 588   4.1  44.3   0.0  0.250  0.250  55.3   0.0
# 589  20.9  17.5  11.1  0.569  0.597  16.4   4.2
# 590  38.4  16.4  11.7  0.610  0.648  21.3   9.1
#
# [591 rows x 28 columns]

# %% [markdown]
# Now, Let's see the count of players based on the position they play:

# %%
nba_df['POS'].value_counts()
# Out:
# G      210
# F      178
# G-F     68
# C       44
# F-C     37
# C-F     27
# F-G     27
# Name: POS, dtype: int64

# %% [markdown]
# We see that there are 2 different classifications for same position group (i.e) 'G-F' and 'F-G' as well as 'F-C' and 'C-F'. Let's fix this so that they are counted together as one.

# %%
nba_df.loc[nba_df['POS'] == 'C-F','POS'] = 'F-C'
nba_df.loc[nba_df['POS'] == 'F-G','POS'] = 'G-F'

# %%
nba_df['POS'].value_counts()
# Out:
# G      210
# F      178
# G-F     95
# F-C     64
# C       44
# Name: POS, dtype: int64

# %% [markdown]
# Now, we can see that the players are counted correctly

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FULL NAME  591 non-null    object
#  1   POS        591 non-null    object
#  2   AGE        591 non-null    float64
#  3   TEAM       591 non-null    object
#  4   GP         591 non-null    int64
#  5   MPG        591 non-null    float64
#  6   PPG        591 non-null    float64
#  7   RPG        591 non-null    float64
#  8   APG        591 non-null    float64
#  9   SPG        591 non-null    float64
#  10  BPG        591 non-null    float64
#  11  TOPG       591 non-null    float64
#  12  FTA        591 non-null    int64
#  13  FT%        591 non-null    float64
#  14  2PA        591 non-null    int64
#  15  2P%        591 non-null    float64
#  16  3PA        591 non-null    int64
#  17  3P%        591 non-null    float64
#  18  VI         591 non-null    float64
#  19  ORTG       591 non-null    float64
#  20  DRTG       591 non-null    float64
#  21  MIN%       591 non-null    float64
#  22  USG%       591 non-null    float64
#  23  TO%        591 non-null    float64
#  24  eFG%       591 non-null    float64
#  25  TS%        591 non-null    float64
#  26  TRB%       591 non-null    float64
#  27  AST%       591 non-null    float64
# dtypes: float64(21), int64(4), object(3)
# memory usage: 129.4+ KB

# %% [markdown]
# ### Calculating the Fantasy Points a Player Generates Per Game

# %% [markdown]
# Now we need to come up with a system that generates points based on each player's performance and personal stats. The higher points the player generates for the team, the better chance that team wins against any other fantasy team.
#
# Each league can have their own points system, so in our case we have come up with the following system for FPPG (Fantasy Points Per Game) (Used by Draft Kings as well)
#
# + Points * (1)
# + 3PTM * (0.5)
# + Rebounds * (1.25)
# + Assists * (1.5)
# + Steals * (2)
# + Blocks * (2)
# + Turnovers * (-0.5)
#
# Multipliying the player's stats with the aforementioned values and combining them together will give us the FPPG each player generates

# %%
nba_df['FPPG'] = (nba_df['PPG'] * 1.0) + (nba_df['APG'] * 1.5) + (nba_df['RPG'] * 1.25) + (nba_df['SPG'] * 2.0) + (nba_df['BPG'] * 2.0) + (nba_df['TOPG'] * -0.5)

# %% [markdown]
# Now we have calculated the FPPG each player generated last season, now we need a metric that measures the potential each player possesses and will contribute to his team next season..
#
# So we need to check for the most important ability each player should possess: **Availability**
#
# So we shall create a new metric called 'MAXPotential' which combines the FPPG (Fantasy Points Per Game), VI (Versatility Index: i.e a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10.) and GP (Games Played)
#
# The formula we've come up with is as follows: (VI + (GP/10)^0.333) / 2

# %%
nba_df['MAXPotential'] = (nba_df['FPPG']/4 + nba_df['VI'] + (np.power((nba_df['GP']), 0.333))) / 3 
nba_df['MAXPotential'] = nba_df['MAXPotential'].round(decimals=0)

# %%
nba_df.head(5)
# Out:
#                   FULL NAME  POS    AGE TEAM  GP   MPG   PPG   RPG  APG   SPG  \
# 0              Steven Adams    C  27.07  OKC  63  26.7  10.9   9.3  2.3  0.81
# 1               Bam Adebayo  F-C  23.08  MIA  72  33.6  15.9  10.2  5.1  1.14
# 2         LaMarcus Aldridge  F-C  35.07  SAN  53  33.1  18.9   7.4  2.4  0.68
# 3            Kyle Alexander  F-C  23.81  MIA   2   6.7   1.0   1.5  0.0  0.00
# 4  Nickeil Alexander-Walker    G  21.95  NOR  47  12.6   5.7   1.8  1.9  0.36
#
#     BPG  TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  \
# 0  1.06  1.51  201  0.582  475  0.594    3  0.333   9.2  122.0  101.9  55.6
# 1  1.29  2.82  382  0.691  777  0.564   14  0.143  11.2  116.2  102.2  69.9
# 2  1.64  1.40  191  0.827  637  0.518  157  0.389   8.4  114.7  109.1  68.9
# 3  0.00  0.50    0  0.000    2  0.500    0  0.000   0.0   96.0  108.8  14.0
# 4  0.17  1.15   37  0.676  133  0.391  133  0.346   8.5   93.2  106.4  26.2
#
#    USG%   TO%   eFG%    TS%  TRB%  AST%    FPPG  MAXPotential
# 0  17.3  14.4  0.593  0.604  19.2  13.2  28.960           7.0
# 1  21.2  17.5  0.558  0.597  17.0  24.2  39.750           8.0
# 2  23.4   7.8  0.531  0.570  12.0  11.4  35.690           7.0
# 3   9.9  33.3  0.500  0.500  12.5   0.0   2.625           1.0
# 4  23.3  16.1  0.455  0.473   7.5  21.1  11.285           5.0

# %%
nba_df['MAXPotential'].describe()
# Out:
# count    591.000000
# mean       4.786802
# std        1.794123
# min        0.000000
# 25%        4.000000
# 50%        5.000000
# 75%        6.000000
# max       12.000000
# Name: MAXPotential, dtype: float64

# %% [markdown]
# From this we can see that the average player scores 5.0 on the MAXPotential Index, while top-tier players score above 10 (max 12).

# %% [markdown]
# ### Creating New Dataframes: Classifying Players based on their Position

# %%
g_df = nba_df.loc[nba_df['POS'] == 'G']

# %%
sg_sf_df = nba_df.loc[nba_df['POS'] == 'G-F']

# %%
sf_pf_df = nba_df.loc[nba_df['POS'] == 'F']

# %%
pf_c_df = nba_df.loc[nba_df['POS'] == 'F-C']

# %%
c_df = nba_df.loc[nba_df['POS'] == 'C']

# %% [markdown]
# ### Top Players based on our Metric: MAXPotential

# %% [markdown]
# Thus we have performed our analysis on the players and have classified them based on their positions. Now let us see how our metric has classified the players.
#
# ***For Example***: Let's assume we have a top 5 Pick in the First Round of the Draft, so let us print the top 5 players for each classified position and see who will be best suited to be in our Squad.

# %% [markdown]
# #### For Point Guards/Shooting Guards

# %%
g_df.sort_values(by='MAXPotential',ascending=False,ignore_index=True).head(5)
# Out:
#            FULL NAME POS    AGE TEAM  GP   MPG   PPG  RPG  APG   SPG   BPG  \
# 0  Russell Westbrook   G  31.75  HOU  57  36.0  27.2  7.9  7.0  1.65  0.35
# 1       James Harden   G  30.97  HOU  68  36.5  34.3  6.5  7.5  1.84  0.88
# 2         Trae Young   G  21.90  ATL  60  35.3  29.6  4.2  9.3  1.08  0.13
# 3     Damian Lillard   G  30.09  POR  66  37.5  30.0  4.3  8.0  1.06  0.33
# 4       Kyrie Irving   G  28.39  BRO  20  32.9  27.4  5.2  6.4  1.35  0.50
#
#    TOPG  FTA    FT%   2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  USG%  \
# 0  4.47  380  0.763  1068  0.514  213  0.258  12.7  105.6  102.4  74.9  34.4
# 1  4.49  800  0.865   671  0.556  843  0.355  13.0  120.3  103.3  76.1  36.2
# 2  4.80  559  0.860   681  0.501  568  0.361  11.9  113.9  115.2  73.6  34.9
# 3  2.94  518  0.888   674  0.525  674  0.401  10.8  126.1  115.5  78.1  30.3
# 4  2.60  102  0.922   274  0.522  142  0.394  11.8  118.6  104.1  68.5  32.6
#
#     TO%   eFG%    TS%  TRB%  AST%    FPPG  MAXPotential
# 0  15.0  0.493  0.536  11.5  35.6  49.340          10.0
# 1  14.0  0.543  0.626   9.4  35.9  56.870          10.0
# 2  16.2  0.519  0.595   6.4  45.6  48.820           9.0
# 3  11.0  0.563  0.628   6.0  34.4  48.685           9.0
# 4  10.1  0.546  0.595   8.1  36.7  45.900           9.0

# %% [markdown]
# #### For Shooting Guards/Small Forwards

# %%
sg_sf_df.sort_values(by='MAXPotential',ascending=False,ignore_index=True).head(5)
# Out:
#                  FULL NAME  POS    AGE TEAM  GP   MPG   PPG  RPG  APG   SPG  \
# 0              Luka Doncic  G-F  21.46  DAL  61  33.6  28.8  9.4  8.8  0.98
# 1              Zach LaVine  G-F  25.43  CHI  60  34.8  25.5  4.8  4.2  1.45
# 2             Jayson Tatum  G-F  22.45  BOS  66  34.3  23.4  7.0  3.0  1.42
# 3  Shai Gilgeous-Alexander  G-F  22.09  OKC  70  34.7  19.0  5.9  3.3  1.13
# 4             Jaylen Brown  G-F  23.81  BOS  57  33.9  20.3  6.4  2.1  1.16
#
#     BPG  TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  \
# 0  0.23  4.28  562  0.758  713  0.575  541  0.316  15.9  115.6  104.0  69.9
# 1  0.47  3.43  334  0.802  716  0.496  484  0.380   9.2  106.9  108.4  72.4
# 2  0.86  2.33  313  0.812  758  0.479  469  0.403   9.2  110.5  103.5  71.5
# 3  0.67  1.93  357  0.807  762  0.513  251  0.347   8.3  111.3  106.4  72.3
# 4  0.35  2.19  243  0.724  549  0.543  338  0.382   7.7  110.2  101.6  70.7
#
#    USG%   TO%   eFG%    TS%  TRB%  AST%    FPPG  MAXPotential
# 0  36.8  14.8  0.531  0.586  14.7  45.7  54.030          11.0
# 1  31.7  13.3  0.526  0.568   7.7  21.7  39.925           8.0
# 2  28.6  10.1  0.527  0.567  10.9  14.5  40.045           8.0
# 3  23.6  10.3  0.515  0.569   9.4  15.2  33.960           7.0
# 4  24.7  11.2  0.554  0.583  10.1   9.7  33.375           7.0

# %% [markdown]
# #### For Small Forwards/Power Forwards

# %%
sf_pf_df.sort_values(by='MAXPotential',ascending=False,ignore_index=True).head(5)
# Out:
#                FULL NAME POS    AGE TEAM  GP   MPG   PPG   RPG   APG   SPG  \
# 0  Giannis Antetokounmpo   F  25.69  MIL  63  30.4  29.5  13.6   5.6  0.98
# 1           LeBron James   F  35.62  LAL  67  34.6  25.3   7.8  10.2  1.16
# 2          Kawhi Leonard   F  29.13  LAC  57  32.4  27.1   7.1   4.9  1.81
# 3            Ben Simmons   F  24.07  PHI  57  35.4  16.4   7.8   8.0  2.11
# 4        Khris Middleton   F  29.01  MIL  62  29.9  20.9   6.2   4.3  0.85
#
#     BPG  TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  \
# 0  1.05  3.65  629  0.633  945  0.631  293  0.304  17.2  116.1   90.2  63.4
# 1  0.54  3.90  381  0.693  878  0.564  425  0.348  14.6  115.4  103.8  72.0
# 2  0.58  2.61  402  0.886  808  0.506  325  0.378  12.1  117.0  101.9  67.5
# 3  0.58  3.51  298  0.621  641  0.582    7  0.286  11.4  115.2  100.7  73.7
# 4  0.11  2.19  227  0.916  593  0.546  354  0.415  11.0  118.1   97.8  62.3
#
#    USG%   TO%   eFG%    TS%  TRB%  AST%    FPPG  MAXPotential
# 0  37.5  13.2  0.589  0.613  22.1  34.2  57.135          12.0
# 1  31.5  15.1  0.550  0.577  12.3  49.1  51.800          11.0
# 2  33.0  10.2  0.524  0.589  11.3  26.5  46.800           9.0
# 3  20.9  20.4  0.580  0.601  12.2  33.8  41.775           9.0
# 4  26.3  11.5  0.575  0.619  10.2  22.2  35.925           8.0

# %% [markdown]
# #### For Power Forwards/Centers

# %%
pf_c_df.sort_values(by='MAXPotential',ascending=False,ignore_index=True).head(5)
# Out:
#             FULL NAME  POS    AGE TEAM  GP   MPG   PPG   RPG  APG   SPG   BPG  \
# 0       Anthony Davis  F-C  27.43  LAL  62  34.4  26.1   9.3  3.2  1.47  2.31
# 1  Karl-Anthony Towns  F-C  24.75  MIN  35  33.9  26.5  10.8  4.4  0.94  1.20
# 2    Domantas Sabonis  F-C  24.28  IND  62  34.8  18.5  12.4  5.0  0.73  0.48
# 3         Joel Embiid  F-C  26.42  PHI  51  29.5  23.0  11.6  3.0  0.86  1.29
# 4         Bam Adebayo  F-C  23.08  MIA  72  33.6  15.9  10.2  5.1  1.14  1.29
#
#    TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  USG%  \
# 0  2.48  525  0.846  878  0.546  218  0.330  10.7  120.3  100.6  71.6  29.3
# 1  3.14  226  0.796  345  0.586  277  0.412  12.7  120.7  104.0  70.7  28.8
# 2  2.76  296  0.723  780  0.565   67  0.254  12.0  115.0   99.1  72.5  23.3
# 3  3.12  436  0.807  630  0.516  172  0.331  12.6  113.0   96.8  61.5  33.0
# 4  2.82  382  0.691  777  0.564   14  0.143  11.2  116.2  102.2  69.9  21.2
#
#     TO%   eFG%    TS%  TRB%  AST%    FPPG  MAXPotential
# 0  10.4  0.536  0.610  14.8  15.1  48.845           9.0
# 1  13.2  0.600  0.642  16.8  22.8  49.310           9.0
# 2  14.9  0.551  0.587  19.6  21.7  42.540           9.0
# 3  13.8  0.512  0.590  21.7  16.9  44.740           9.0
# 4  17.5  0.558  0.597  17.0  24.2  39.750           8.0

# %% [markdown]
# #### For Pure Centers

# %%
c_df.sort_values(by='MAXPotential',ascending=False,ignore_index=True).head(5)
# Out:
#            FULL NAME POS    AGE TEAM  GP   MPG   PPG   RPG  APG   SPG   BPG  \
# 0       Nikola Jokic   C  25.49  DEN  73  32.0  19.9   9.7  7.0  1.16  0.60
# 1     Nikola Vucevic   C  29.81  ORL  62  32.2  19.6  10.8  3.6  0.87  0.76
# 2     Andre Drummond   C  27.01  DET  49  33.7  17.8  15.8  2.8  1.98  1.67
# 3  Jonas Valanciunas   C  28.27  MEM  70  26.4  14.9  11.3  1.9  0.44  1.10
# 4       Jusuf Nurkic   C  25.98  POR   8  31.7  17.6  10.3  4.0  1.38  2.00
#
#    TOPG  FTA    FT%  2PA    2P%  3PA    3P%    VI   ORTG   DRTG  MIN%  USG%  \
# 0  3.08  301  0.817  816  0.594  255  0.314  13.8  118.8  101.5  66.6  26.6
# 1  1.42  167  0.784  744  0.531  289  0.339  11.3  113.4  103.0  67.1  25.8
# 2  3.55  255  0.584  658  0.546   21  0.048  11.0  104.3   97.5  70.3  25.5
# 3  1.81  200  0.740  650  0.615   91  0.352  10.4  119.1  100.1  54.9  21.6
# 4  2.38   35  0.886   99  0.525   10  0.200  11.3  115.5   98.3  65.9  24.0
#
#     TO%   eFG%    TS%  TRB%  AST%    FPPG  MAXPotential
# 0  15.8  0.565  0.605  17.1  35.2  44.505          10.0
# 1   7.4  0.525  0.549  18.0  19.5  41.050           9.0
# 2  18.0  0.531  0.550  26.6  14.0  47.275           9.0
# 3  13.3  0.605  0.630  22.6  10.9  34.050           8.0
# 4  13.2  0.505  0.567  17.0  19.1  42.045           8.0

# %% [markdown]
# From this, We can see the top 5 players of each classified position and decide upon whom we should select during draft night based on the metric that we have created (i.e) MAXPotential.

# %% [markdown]
# #### Thus in this analysis, We have used our very own metrics to generate Draft Boards (based on position) to analyze and scout players based on their previous year's regular season stats to decide who should we draft to be on our squad come Opening Day!
